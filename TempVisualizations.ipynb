# %%
import pandas as pd
import seaborn as sns
import numpy as np

df = pd.read_csv("bankPayments.csv")
df["category"] = df["category"].str.slice(4,-1)
df.head()
# Out:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#          category  amount  fraud
# 0  transportation    4.55      0
# 1  transportation   39.68      0
# 2  transportation   26.89      0
# 3  transportation   17.25      0
# 4  transportation   35.72      0

# %%
df2 = df[["category", "fraud"]]
df2.groupby("category").aggregate('sum')
# Out:
#                     fraud
# category
# barsandrestaurants    120
# contents                0
# fashion               116
# food                    0
# health               1696
# home                  302
# hotelservices         548
# hyper                 280
# leisure               474
# otherservices         228
# sportsandtoys        1982
# tech                  158
# transportation          0
# travel                578
# wellnessandbeauty     718

# %%
v1 = sns.barplot(df2, x="fraud", y="category", estimator="sum")
v1.set(xlabel="Fraud Count", ylabel="Category", title="Visualizing the number of Fraudulent transactions for each Category")
# Out:
# [Text(0.5, 0, 'Fraud Count'),
#  Text(0, 0.5, 'Category'),
#  Text(0.5, 1.0, 'Visualizing the number of Fraudulent transactions for each Category')]

# %%
df3 = df[["category", "amount"]]
df3.groupby("category").aggregate('mean')
# Out:
#                          amount
# category
# barsandrestaurants    43.461014
# contents              44.547571
# fashion               65.666642
# food                  37.070405
# health               135.621367
# home                 165.670846
# hotelservices        205.614249
# hyper                 45.970421
# leisure              288.911303
# otherservices        135.881524
# sportsandtoys        215.715280
# tech                 120.947937
# transportation        26.958187
# travel              2250.409190
# wellnessandbeauty     65.511221

# %%
v2 = sns.barplot(df3, x="amount", y="category")
v2.set(xlabel="Average Amount", title="Visualizing the average amount spent per Transaction for each Category")
# Out:
# [Text(0.5, 0, 'Average Amount'),
#  Text(0.5, 1.0, 'Visualizing the average amount spent per Transaction for each Category')]
